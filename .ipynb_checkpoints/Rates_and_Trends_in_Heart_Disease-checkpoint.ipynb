# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import scipy.stats as stats

# %%
# Read in dataset for Rates and Trends in Heart Disease Between 1999-2019
Heart_disease_df = pd.read_csv("Resources/Rates_and_Trends_in_Heart_Disease_2009_2019.csv")
Heart_disease_df["Year"] = Heart_disease_df["Year"].astype(float)
Heart_disease_df.head()
# Out:
#      Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 0  1999.0           AL      Autauga          County       NVSS
# 1  2013.0           AL      Autauga          County       NVSS
# 2  2014.0           AL      Autauga          County       NVSS
# 3  2005.0           AL      Autauga          County       NVSS
# 4  2012.0           AL      Autauga          County       NVSS
#
#                      Class              Topic  Data_Value Data_Value_Unit  \
# 0  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 1  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 2  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 3  Cardiovascular Diseases  All heart disease         NaN     per 100,000
# 4  Cardiovascular Diseases  All heart disease         NaN     per 100,000
#
#                                     Data_Value_Type  ... Data_Value_Footnote  \
# 0  Age-Standardized, Spatiotemporally Smoothed Rate  ...    Value suppressed
# 1  Age-Standardized, Spatiotemporally Smoothed Rate  ...    Value suppressed
# 2  Age-Standardized, Spatiotemporally Smoothed Rate  ...    Value suppressed
# 3  Age-Standardized, Spatiotemporally Smoothed Rate  ...    Value suppressed
# 4  Age-Standardized, Spatiotemporally Smoothed Rate  ...    Value suppressed
#
#   Confidence_limit_Low  Confidence_limit_High  StratificationCategory1  \
# 0                  NaN                    NaN                Age group
# 1                  NaN                    NaN                Age group
# 2                  NaN                    NaN                Age group
# 3                  NaN                    NaN                Age group
# 4                  NaN                    NaN                Age group
#
#     Stratification1 StratificationCategory2                Stratification2  \
# 0  Ages 35-64 years                    Race  American Indian/Alaska Native
# 1  Ages 35-64 years                    Race  American Indian/Alaska Native
# 2  Ages 35-64 years                    Race  American Indian/Alaska Native
# 3  Ages 35-64 years                    Race  American Indian/Alaska Native
# 4  Ages 35-64 years                    Race  American Indian/Alaska Native
#
#   StratificationCategory3 Stratification3 LocationID
# 0                     Sex         Overall       1001
# 1                     Sex         Overall       1001
# 2                     Sex         Overall       1001
# 3                     Sex         Overall       1001
# 4                     Sex         Overall       1001
#
# [5 rows x 21 columns]

# %%
# Get relevant columns
Clean_Heart_disease_df = Heart_disease_df[["Year", "LocationAbbr","LocationDesc", "Topic", "Data_Value_Unit", "Stratification1",\
                                           "Stratification2", "Stratification3", "LocationID"]]

# Drop any rows with null values
Clean_Heart_disease_null = Clean_Heart_disease_df.dropna(axis=0, how = "any")
Clean_Heart_disease_null.head()
# Out:
#      Year LocationAbbr LocationDesc              Topic Data_Value_Unit  \
# 0  1999.0           AL      Autauga  All heart disease     per 100,000
# 1  2013.0           AL      Autauga  All heart disease     per 100,000
# 2  2014.0           AL      Autauga  All heart disease     per 100,000
# 3  2005.0           AL      Autauga  All heart disease     per 100,000
# 4  2012.0           AL      Autauga  All heart disease     per 100,000
#
#     Stratification1                Stratification2 Stratification3  LocationID
# 0  Ages 35-64 years  American Indian/Alaska Native         Overall        1001
# 1  Ages 35-64 years  American Indian/Alaska Native         Overall        1001
# 2  Ages 35-64 years  American Indian/Alaska Native         Overall        1001
# 3  Ages 35-64 years  American Indian/Alaska Native         Overall        1001
# 4  Ages 35-64 years  American Indian/Alaska Native         Overall        1001

# %%
# Get a brief summary of the Clean_Heart_disease_null Dataframe
Clean_Heart_disease_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 9 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Year             1048575 non-null  float64
#  1   LocationAbbr     1048575 non-null  object
#  2   LocationDesc     1048575 non-null  object
#  3   Topic            1048575 non-null  object
#  4   Data_Value_Unit  1048575 non-null  object
#  5   Stratification1  1048575 non-null  object
#  6   Stratification2  1048575 non-null  object
#  7   Stratification3  1048575 non-null  object
#  8   LocationID       1048575 non-null  int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 72.0+ MB

# %%
Heart_disease_rename = Clean_Heart_disease_null.rename(columns = {"LocationAbbr": "US States", "LocationDesc": "US County",\
                                                               "Topic": "Heart Disease Type", "Data_Value_Unit": "Rate per 100,000 population",\
                                                               "Stratification1": "Age range", "Stratification2": "Ethnicity", "Stratification3": "Gender"})
Heart_disease_rename.head()
# Out:
#      Year US States US County Heart Disease Type Rate per 100,000 population  \
# 0  1999.0        AL   Autauga  All heart disease                 per 100,000
# 1  2013.0        AL   Autauga  All heart disease                 per 100,000
# 2  2014.0        AL   Autauga  All heart disease                 per 100,000
# 3  2005.0        AL   Autauga  All heart disease                 per 100,000
# 4  2012.0        AL   Autauga  All heart disease                 per 100,000
#
#           Age range                      Ethnicity   Gender  LocationID
# 0  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 1  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 2  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 3  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 4  Ages 35-64 years  American Indian/Alaska Native  Overall        1001

# %%
# Filter the Dataframe to include only the desired years
filtered_Heart_disease_rename = Heart_disease_rename[(Heart_disease_rename['Year'] >= 2009) & (Heart_disease_rename['Year'] <= 2019)]
filtered_Heart_disease_rename.head(20)
# Out:
#       Year US States US County Heart Disease Type Rate per 100,000 population  \
# 1   2013.0        AL   Autauga  All heart disease                 per 100,000
# 2   2014.0        AL   Autauga  All heart disease                 per 100,000
# 4   2012.0        AL   Autauga  All heart disease                 per 100,000
# 5   2010.0        AL   Autauga  All heart disease                 per 100,000
# 6   2009.0        AL   Autauga  All heart disease                 per 100,000
# 7   2011.0        AL   Autauga  All heart disease                 per 100,000
# 9   2019.0        AL   Autauga  All heart disease                 per 100,000
# 10  2018.0        AL   Autauga  All heart disease                 per 100,000
# 12  2016.0        AL   Autauga  All heart disease                 per 100,000
# 13  2015.0        AL   Autauga  All heart disease                 per 100,000
# 20  2017.0        AL   Autauga  All heart disease                 per 100,000
# 21  2015.0        AL   Autauga         All stroke                 per 100,000
# 22  2010.0        AL   Autauga         All stroke                 per 100,000
# 23  2011.0        AL   Autauga         All stroke                 per 100,000
# 24  2018.0        AL   Autauga         All stroke                 per 100,000
# 27  2014.0        AL   Autauga         All stroke                 per 100,000
# 29  2012.0        AL   Autauga         All stroke                 per 100,000
# 30  2019.0        AL   Autauga         All stroke                 per 100,000
# 31  2009.0        AL   Autauga         All stroke                 per 100,000
# 34  2017.0        AL   Autauga         All stroke                 per 100,000
#
#            Age range                      Ethnicity   Gender  LocationID
# 1   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 2   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 4   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 5   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 6   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 7   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 9   Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 10  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 12  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 13  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 20  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 21  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 22  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 23  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 24  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 27  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 29  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 30  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 31  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
# 34  Ages 35-64 years  American Indian/Alaska Native  Overall        1001
